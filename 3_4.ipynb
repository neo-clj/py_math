# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import sympy

# %% [markdown]
# # 91-94: Verifying Zeros Using a Graphing Device

# %% [markdown]
# ## 91. $$ x^{3} - 3x^{2} - 4x + 12 = 0; [-4, 4] by [-15, 15] $$

# %%
x = np.linspace(-5, 5, 10000)
y = (x**3) - (3 * x**2) - (4 * x) + 12

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y)

plt.ylim(-15, 15)
plt.xlim(-4, 4)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# ## 92. $$ x^{4} - 5x^{2} + 4 = 0; [-4, 4] by [-30, 30] $$

# %%
x = np.linspace(-5, 5, 10000)
y = (x**4) - (5 * x**2) + 4

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y)

plt.ylim(-30, 30)
plt.xlim(-4, 4)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="833.3666666666667">

# %% [markdown]
# ## 93. $$ 2x^{4} - 5x^{3} - 14x^{2} + 5x + 12 = 0; [-2, 5] by [-40, 40] $$

# %%
x = np.linspace(-5, 5, 10000)
y = (2 * x**4) - (5 * x**3) - (14 * x**2) + (5 * x) + 12

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y)

plt.ylim(-40, 40)
plt.xlim(-2, 5)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ## 94. $$ 3x^{3} + 8x^{2} + 5x + 2 = 0; [-3, 3] by [-10, 10] $$

# %%
x = np.linspace(-5, 5, 10000)
y = (3 * x**3) + (8 * x**2) + (5 * x) + 2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y)

plt.ylim(-10, 10)
plt.xlim(-3, 3)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# # 95-98: Finding Zeros Using Graphing Device
# ## Use a graphing device to find all real solutions of the equation, rounded to two decimal places.

# %% [markdown]
# # 95 $$ x^{4} - x - 4 = 0 $$

# %%
x = np.linspace(-5, 5, 10000)
y = x**4 - x - 4

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y)

plt.ylim(-10, 10)
plt.xlim(-4.5, 4.5)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# # 96 $$ 2x^{3} - 8x^{2} + 9x - 9 = 0 $$

# %%
x = np.linspace(-5, 5, 10000)
y = (2 * x**3) - (8 * x**2) + (9 * x) - 9

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y)

plt.ylim(-50, 50)
plt.xlim(-10, 10)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# # 97 $$ 4.00x^{4} + 4.00x^{3} - 10.96x^{2} - 5.88x + 9.09 = 0 $$

# %%
x = np.linspace(-5, 5, 10000)
y = (4.00 * x**4) + (4.00 * x**3) - (10.96 * x**2) - (5.88 * x) + (9.09)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y)

plt.ylim(-15, 15)
plt.xlim(-4, 4)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# # 98 $$ x^{5} + 2.00x^{4} + 0.96x^{3} + 5.00x^{2} + 10.00x + 4.80 = 0 $$

# %%
x = np.linspace(-5, 5, 10000)
y = (x**5) + (2.00 * x**4) + (0.96 * x**3) + (5.00 * x**2) + (10.00 * x) + 4.80

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y)

plt.ylim(-15, 15)
plt.xlim(-5, 5)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
