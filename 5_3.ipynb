# %%
# %matplotlib widget

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from basic_units import radians

# %%
from IPython.display import display, Math, Latex

# %%
x1 = np.linspace(-2*np.pi, 2*np.pi, 10000)
y1 = 2 * np.sin(x1)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')

plt.ylim(-3, 3)
plt.xlim(-10, 10)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x1 = np.linspace(-3*np.pi, 3*np.pi, 10000)

y1 = np.cos(x1)
y2 = -3 * np.cos(x1)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x1, y2)

plt.ylim(-3.5, 3.5)
plt.xlim(-10, 10)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x1 = np.linspace(-3.2, 6.4, 10000)

y1 = np.sin(x1)
y2 = 1/2 * np.sin(x1)
y3 = 3 * np.sin(x1)
y4 = -2 * np.sin(x1)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x1, y2)
plt.plot(x1, y3)
plt.plot(x1, y4)

plt.ylim(-4, 4)
plt.xlim(-4.5, 7.5)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x1 = np.linspace(0, 2*np.pi * 1, 10000)
x2 = np.linspace(0, 2*np.pi * 2, 10000)
x3 = np.linspace(0, 2*np.pi * 3, 10000)
x4 = np.linspace(0, 2*np.pi / 2, 10000)

y1 = np.sin(x1)
y2 = np.sin(1/2 * x2)
y3 = np.sin(1/3 * x3)
y4 = np.sin(2 * x4)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)

plt.ylim(-2.5, 2.5)
plt.xlim(0, 18.9)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x1 = np.linspace(-3*np.pi, 3*np.pi, 10000)

y1 = np.cos(x1)
y2 = 2 + np.cos(x1)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, xunits=radians)
plt.plot(x1, y2, xunits=radians)
plt.hlines(y=2, xunits=radians, xmin=-20, xmax=20, linestyles='dotted',)

plt.ylim(-3.5, 3.5)
plt.xlim(-10, 10)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$ f(x) = \frac{sin(x)}{x} $$

# %%
x1 = np.linspace(-5*np.pi, 5*np.pi, 100000)
y1 = np.sin(x1) / x1

x2 = np.linspace(-4*np.pi, 4*np.pi, 100000)
y2 = np.sin(4 * x2) / (2 * x1)


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)

plt.ylim(-1.5, 2)
plt.xlim(-6*np.pi, 6*np.pi)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 82

# %%
x1 = np.linspace(-4*np.pi, 4*np.pi, 100000)
y1 = np.sin(4 * x1) / (2 * x1)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')

plt.ylim(-0.5, 2.5)
plt.xlim(-4*np.pi, 4*np.pi)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.sin(0.00000001) / 0.00000001
# Out:
# 1.0

# %% [markdown]
# exercise 81

# %%
x1 = np.linspace(-18*np.pi, 18*np.pi, 100000)
y1 = (1 - np.cos(x1)) / x1

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')

plt.ylim(-2, 2)
plt.xlim(-20*np.pi, 20*np.pi)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 55: $$ f(x) = cos(100x)$$

# %%
x1 = np.linspace((-2*np.pi / 100)*3, (2*np.pi / 100)*3, 10000)
y1 = np.cos(100 * x1)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)

plt.ylim(-1.5, 1.5)
plt.xlim(-0.25, 0.25)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 57: $$ f(x) = sin(\frac{x}{40})$$

# %%
x1 = np.linspace((-2*np.pi * 40)*3, (2*np.pi * 40)*3, 1000000)
y1 = np.sin(x1 / 40)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)

plt.ylim(-1.5, 1.5)
plt.xlim((-2*np.pi * 40)*3, (2*np.pi * 40)*3)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
754 / np.pi
# Out:
# 240.00565418257818

# %% [markdown]
# exercise 59: $$ y = tan(25x) $$

# %%
x1 = np.linspace((-np.pi / 25)*3, (np.pi / 25)*3, 1000000)
y1 = np.tan(25 * x1)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)

plt.ylim(-20, 20)
plt.xlim((-np.pi / 25)*3, (np.pi / 25)*3)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 61: $$ y = sin^{2} 20x $$

# %%
x1 = np.linspace((-2*np.pi / 20)*3, (2*np.pi / 20)*3, 10000)
y1 = (np.sin(20 * x1)) ** 2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)

plt.ylim(-2., 2.)
plt.xlim(-1, 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$ y = sin^{2} x $$

# %%
x1 = np.linspace((-2*np.pi), (2*np.pi), 10000)
y1 = (np.sin(x1)) ** 2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)

plt.ylim(-2., 2.)
plt.xlim(-2*np.pi - 1, 2*np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$ y = cos^{2} x $$

# %%
x1 = np.linspace((-2*np.pi), (2*np.pi), 10000)
y1 = (np.cos(x1)) ** 2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)

plt.ylim(-2., 2.)
plt.xlim(-2*np.pi - 1, 2*np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 63:
# Graph f, g, and f + g on a common screen to illustrate graphical addition.
#
# $$ f(x) = x $$
# $$ g(x) = sin(x) $$

# %%
x1 = np.linspace(-2*np.pi, 2*np.pi, 10000)
x2 = np.linspace(-2*np.pi, 2*np.pi, 10000)
x3 = np.linspace(-2*np.pi, 2*np.pi, 10000)

y1 = x1
y2 = np.sin(x2)
y3 = y1 + y2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-2*np.pi - 1, 2*np.pi + 1)
plt.xlim(-2*np.pi - 1, 2*np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 64:
# Graph f, g, and f + g on a common screen to illustrate graphical addition.
#
# $$ f(x) = sin(x) $$
# $$ g(x) = sin(2x) $$

# %%
x1 = np.linspace(-2*np.pi, 2*np.pi, 10000)
x2 = np.linspace(-2*np.pi, 2*np.pi, 10000)
x3 = np.linspace(-2*np.pi, 2*np.pi, 10000)

y1 = np.sin(x1)
y2 = np.sin(2 * x2)
y3 = y1 + y2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-2, 2)
plt.xlim(-2*np.pi - 1, 2*np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 65:
# Graph f, g, and f + g on a common screen to illustrate graphical addition.
#
# $$ f(x) = sin(3x) $$
# $$ g(x) = cos(\frac{1}{2}x) $$

# %%
x1 = np.linspace((-2*np.pi) * 2, (2*np.pi) * 2, 1000000)
x2 = np.linspace((-2*np.pi) * 2, (2*np.pi) * 2, 1000000)
x3 = np.linspace((-2*np.pi) * 2, (2*np.pi) * 2, 1000000)

y1 = np.sin(3 * x1)
y2 = np.cos(x2 / 2)
y3 = y1 + y2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-5, 5)
plt.xlim((-2*np.pi) * 2 - 1, (2*np.pi) * 2 + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 66:
# Graph f, g, and f + g on a common screen to illustrate graphical addition.
#
# $$ f(x) = \frac{1}{2} sin(5x) $$
# $$ g(x) = -cos(2x) $$

# %%
x1 = np.linspace(-np.pi, np.pi, 10000)
x2 = np.linspace(-np.pi, np.pi, 10000)
x3 = np.linspace(-np.pi, np.pi, 10000)

y1 = 0.5 * np.sin(5 * x1)
y2 = -np.cos(2 * x2)
y3 = y1 + y2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-2, 2)
plt.xlim(-np.pi - 1, np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 67:
# Graph the three functions on a common screen. How are the graphs related?
# $$ y = x^{2} $$
# $$ y = -x^{2} $$
#
# $$ y = x^{2} sin(x) $$

# %%
x1 = np.linspace((-2*np.pi) * 5, (2*np.pi) * 5, 10000)
x2 = x1
x3 = x1

y1 = x1 ** 2
y2 = -(x2 ** 2)
y3 = (x3 ** 2) * np.sin(x3)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-1000, 1000)
plt.xlim((-2*np.pi) * 5 - 1, (2*np.pi) * 5 + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Graph the three functions on a common screen. How are the graphs related?
# $$ y = x^{2} $$
# $$ y = -x^{2} $$
# $$ y = x^{2} cos(x) $$

# %%
x1 = np.linspace((-2*np.pi) * 5, (2*np.pi) * 5, 10000)
x2 = x1
x3 = x1

y1 = x1 ** 2
y2 = -(x2 ** 2)
y3 = (x3 ** 2) * np.cos(x3)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-1000, 1000)
plt.xlim((-2*np.pi) * 5 - 1, (2*np.pi) * 5 + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Example 8, page 427:
# Graph the functions
# $$ y = x^{2} ;;
#  y = -x^{2} ;;
#  y = x^{2} cos(6 \pi x) $$
# on a common screen.

# %%
x1 = np.linspace((-2*np.pi), (2*np.pi), 1000000)
x2 = x1
x3 = x1

y1 = x1 ** 2
y2 = -(x2 ** 2)
y3 = (x3 ** 2) * np.cos(6 * np.pi * x3)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-2, 2)
plt.xlim(-1.5, 1.5)
plt.grid(True)
# Out:
# /tmp/ipykernel_112271/412972795.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# example 9, page 428: graph the function
#     $$ f(x) = \cos2\pi x \cos16\pi x $$

# %%
x1 = np.linspace((-2*np.pi), (2*np.pi), 1000000)
x2 = x1
x3 = x1

y1 = np.cos(2 * np.pi * x1)
y2 = -np.cos(2 * np.pi * x2)
y3 = np.cos(2 * np.pi * x3) * np.cos(16 * np.pi * x3)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-2, 2)
plt.xlim(-1.5, 1.5)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x1 = np.linspace((-2*np.pi), (2*np.pi), 1000000)
x2 = x1
x3 = x1

y1 = np.cos(x1)
y2 = -np.cos(x2)
y3 = np.cos(x3) * np.cos(2 * x3)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-2, 2)
plt.xlim((-2*np.pi) - 1, (2*np.pi) + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x1 = np.linspace((-2*np.pi), (2*np.pi), 1000000)
x2 = x1
x3 = x1

y1 = np.sin(x1)
y2 = -np.sin(x2)
y3 = np.sin(x3) * np.sin(2 * x3)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)

plt.ylim(-1.2, 1.2)
plt.xlim((-2*np.pi) - .1, (2*np.pi) + .1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$ \sin x^{2} $$

# %%
x1 = np.linspace(-4*np.pi, 4*np.pi, 100000)
y1 = np.sin(x1 ** 2)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')

plt.ylim(-5, 5)
plt.xlim(-4*np.pi, 4*np.pi)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$ \sin \sqrt x $$

# %%
x1 = np.linspace(0, 400*np.pi, 100000)
y1 = np.sin(x1 ** (1/2))

x2 = np.linspace(-400*np.pi, -0.0000000001, 100000)
y2 = np.sin((-1 * x2) ** (1/2))

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')
plt.plot(x2, y2, color='b')

plt.ylim(-5, 5)
plt.xlim(-400*np.pi - 1, 400*np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# exercise 89. Use a graphing device to graph the following functions. From the graph, determine whether the function is periodic; if it is periodic, find the period.

# %% [markdown]
# (a)
# $$ y = | \sin x| $$

# %%
x1 = np.linspace(-2*np.pi, 2*np.pi, 10000)
y1 = abs(np.sin(x1))

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')

plt.ylim(-3, 3)
plt.xlim(-10, 10)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# (b)
# $$ y = \sin |x| $$

# %%
x1 = np.linspace(-4*np.pi, 4*np.pi, 10000)
y1 = np.sin(abs(x1))

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')

plt.ylim(-3, 3)
plt.xlim(-4*np.pi - 1, 4*np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# (c)
# $$ y = 2^{\cos x} $$

# %%
x = np.linspace(-4*np.pi, 4*np.pi, 10000)
y = 2 ** (np.cos(x))

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y, color='b')

plt.ylim(-3, 3)
plt.xlim(-4*np.pi - 1, 4*np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# (d)
# $$ y = x - \left \lfloor{x}\right \rfloor  $$

# %%
steps = np.arange(-5, 6)
xs = []
ys = []

for step in steps:
    x = np.array(np.linspace(step, step + 0.999, 1000))
    y = x - np.floor(x)
    xs.append(x)
    ys.append(y)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

for x, y in zip(xs, ys):
    plt.plot(x, y, color='r')
    
plt.ylim(-2, 2)
plt.xlim(-6, 7)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# (e)
# $$ y = \cos (\sin x) $$

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 10000)
y = np.cos(np.sin(x))

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y, color='b')

plt.ylim(-0.5, 1.5)
plt.xlim(-2*np.pi - 1, 2*np.pi + 1)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# (f)
# $$ y = \cos(x^{2}) $$

# %%
x = np.linspace(-4*np.pi, 4*np.pi, 10000)
y = np.cos(x ** 2)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y, color='b')

plt.ylim(-3, 3)
plt.xlim(-10, 10)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 90. DISCUSS: Sinusoidal Curves   The graph of $y = \sin x$ is the
# same as the graph of $ y = \cos x $ shifted to the right $ \pi / 2 $ units.
# So the sine curve $y = \sin x$ is also at the same time a cosine
# curve: $ y = \cos(x - \frac{\pi}{2})$ . In fact, any sine curve is also a
# cosine curve with a different horizontal shift, and any cosine
# curve is also a sine curve. Sine and cosine curves are collectively referred to as sinusoidal. For the curve whose graph is
# shown, find all possible ways of expressing it as a sine curve
# $ y = a \sin(x - b) $ or as a cosine curve $ y = a \cos(x - b) $.
# Explain why you think you have found all possible choices
# for a and b in each case.

# %% [markdown]
# graph of $ y = \cos(x - \frac{\pi}{2}) $ :

# %%
x = np.linspace(-4*np.pi, 4*np.pi, 10000)
y = np.cos(x - np.pi / 2)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y, color='b')

plt.ylim(-3, 3)
plt.xlim(-10, 10)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# graph of $ y = \sin x $ :

# %%
x = np.linspace(-4*np.pi, 4*np.pi, 10000)
y = np.sin(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x, y, color='b')

plt.ylim(-3, 3)
plt.xlim(-10, 10)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
