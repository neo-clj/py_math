# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import sympy

# %%
# example 9, p. 305

# %%
x1 = np.linspace(-1000, 2.9, 10000)
y1 = (x1**2 - 4*x1 - 5) / (x1 - 3)
#y1 = x1 - 1 - (8 / (x1 - 3))

x2 = np.linspace(3.1, 1000, 10000)
y2 = (x2**2 - 4*x2 - 5) / (x2 - 3)
#y2 = x2 - 1 - (8 / (x2 - 3))

x3 = np.linspace(-1000, 1000, 10000)
y3 = x3 - 1

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3, linestyle='--')
plt.vlines(x=3, ymin=-20, ymax=20, linestyles='--',)

plt.ylim(-20, 20)
plt.xlim(-15, 15)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = np.linspace(-1000, 2.9, 10000)
y1 = x1 - 1 - (8 / (x1 - 3))
#y1 = (x1**2 - 4*x1 - 5) / (x1 - 3)

x2 = np.linspace(3.1, 1000, 10000)
y2 = x2 - 1 - (8 / (x2 - 3))
#y2 = (x2**2 - 4*x2 - 5) / (x2 - 3)

x3 = np.linspace(-1000, 1000, 10000)
y3 = x3 - 1

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3, linestyle='--')
plt.vlines(x=3, ymin=-20, ymax=20, linestyles='--',)

plt.ylim(-20, 20)
plt.xlim(-15, 15)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 69. $$ r(x) = \frac{x^{2}}{x - 2} $$

# %%
x1 = np.linspace(-1000, 1.9, 10000)
y1 = x1 + 2 + (4 / (x1 - 2))

x2 = np.linspace(2.1, 1000, 10000)
y2 = x2 + 2 + (4 / (x2 - 2))

x3 = np.linspace(-1000, 1000, 10000)
y3 = x3 + 2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')
plt.plot(x2, y2, color='b')
plt.plot(x3, y3, linestyle='--', color='r')
plt.vlines(x=2, ymin=-20, ymax=20, linestyles='--', color='r')

plt.ylim(-20, 20)
plt.xlim(-15, 15)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = np.linspace(-1000, 1.9, 10000)
y1 = x1**2 / (x1 - 2)

x2 = np.linspace(2.1, 1000, 10000)
y2 = x2**2 / (x2 - 2)

x3 = np.linspace(-1000, 1000, 10000)
y3 = x3 + 2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')
plt.plot(x2, y2, color='b')
plt.plot(x3, y3, linestyle='--', color='r')
plt.vlines(x=2, ymin=-20, ymax=20, linestyles='--', color='r')

plt.ylim(-20, 20)
plt.xlim(-15, 15)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 71.

# %%
x1 = np.linspace(-1000, -0.1, 10000)
y1 = (x1**2 - 2 * x1 - 8) / x1

x2 = np.linspace(0.1, 1000, 10000)
y2 = (x2**2 - 2 * x2 - 8) / x2

x3 = np.linspace(-1000, 1000, 10000)
y3 = x3 - 2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')
plt.plot(x2, y2, color='b')
plt.plot(x3, y3, linestyle='--', color='r')
plt.vlines(x=0, ymin=-20, ymax=20, linestyles='--', color='r')

plt.ylim(-20, 20)
plt.xlim(-15, 15)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = np.linspace(-1000, -0.1, 10000)
y1 = x1 - 2 - (8 / x1)

x2 = np.linspace(0.1, 1000, 10000)
y2 = x2 - 2 - (8 / x2)

x3 = np.linspace(-1000, 1000, 10000)
y3 = x3 - 2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')
plt.plot(x2, y2, color='b')
plt.plot(x3, y3, linestyle='--', color='r')
plt.vlines(x=0, ymin=-20, ymax=20, linestyles='--', color='r')

plt.ylim(-20, 20)
plt.xlim(-15, 15)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 73.

# %%
x1 = np.linspace(-1000, 2.9, 10000)
y1 = (x1**2 + 5 * x1 + 4) / (x1 - 3)

x2 = np.linspace(3.1, 1000, 10000)
y2 = (x2**2 + 5 * x2 + 4) / (x2 - 3)

x3 = np.linspace(-1000, 1000, 10000)
y3 = x3 + 8

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')
plt.plot(x2, y2, color='b')
plt.plot(x3, y3, linestyle='--', color='r')
plt.vlines(x=3, ymin=-70, ymax=70, linestyles='--', color='r')

plt.ylim(-50, 50)
plt.xlim(-50, 50)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = np.linspace(-1000, 2.9, 10000)
y1 = x1 + 8 + (28 / (x1 - 3))

x2 = np.linspace(3.1, 1000, 10000)
y2 = x2 + 8 + (28 / (x2 - 3))

x3 = np.linspace(-1000, 1000, 10000)
y3 = x3 + 8

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')
plt.plot(x2, y2, color='b')
plt.plot(x3, y3, linestyle='--', color='r')
plt.vlines(x=3, ymin=-50, ymax=50, linestyles='--', color='r')

plt.ylim(-50, 50)
plt.xlim(-50, 50)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">
