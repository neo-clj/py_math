# %%
# %matplotlib notebook

# %%
import numpy as np
import sympy

# %%
import matplotlib.pyplot as plt

# %%
# figure 2, p.332

# %%
bases = np.array([1/2, 1/3, 1/5, 1/10, 2, 3, 5, 10])
xs = np.linspace(-10, 10, 1000000)
yss = []
strings = []

for base in bases:
    ys = base ** xs
    yss.append(ys)
    string = '{0} ** x'.format(base)
    string = sympy.sympify(string)
    strings.append(string)
    
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

for ys, string in zip(yss, strings):
    plt.plot(xs, ys, label=string)
    
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
               ncol=2, mode="expand", borderaxespad=0.)

plt.ylim(-1, 3)
plt.xlim(-3, 3)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 45

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.set_xlim([0, 5])
ax1.set_ylim([0, 20])

ax2.set_xlim([0, 25])
ax2.set_ylim([0, 10**7])

ax3.set_xlim([0, 50])
ax3.set_ylim([0, 10**8])


xs = np.linspace(0, 50, 1000000)
ys1 = 2 ** xs
ys2 = xs ** 5


ax1.plot(xs, ys1)
ax1.plot(xs, ys2)

ax2.plot(xs, ys1)
ax2.plot(xs, ys2)

ax3.plot(xs, ys1)
ax3.plot(xs, ys2)
# Out:
# <img src="data:image/png;base64,..." width="640">
