# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# 17.

# %%
x = sympy.Symbol('x')
sympy.solveset((x - 1) / (x - 10) < 0, x, sympy.S.Reals)
# Out:
# Interval.open(1, 10)

# %%
# 23

# %%
sympy.solveset((x**2 + 2*x - 3) / (3*x**2 - 7*x - 6) > 0, x, sympy.S.Reals)
# Out:
# Union(Interval.open(-oo, -3), Interval.open(-2/3, 1), Interval.open(3, oo))

# %%
# 34

# %%
sympy.solveset((x / 2) >= (5 / (x + 1) + 4), x, sympy.S.Reals)
# Out:
# Union(Interval.Ropen(-2, -1), Interval(9, oo))

# %%
# 37

# %%
x1 = np.linspace(-1000, 1000, 10000)
y1 = x1 ** 2

x2 = np.linspace(-1000, 1000, 10000)
y2 = 3 * x2 + 10 



fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')
plt.plot(x2, y2, color='r')

plt.ylim(-2, 60)
plt.xlim(-15, 15)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 45

# %%
sympy.solveset((x**3 - 2 * x**2 - 5 * x + 6) >= 0, x, sympy.S.Reals)
# Out:
# Union(Interval(-2, 1), Interval(3, oo))

# %%
x1 = np.linspace(-10, 10, 10000)
y1 = x1**3 - 2 * x1**2 - 5 * x1 + 6

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

plt.plot(x1, y1, color='b')

plt.ylim(-10, 10)
plt.xlim(-5, 5)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">
