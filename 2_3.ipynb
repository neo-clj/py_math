# %%
import numpy as np

# %%
# %matplotlib notebook

# %%
import sympy

# %%
import matplotlib.pyplot as plt

# %%
from sympy.abc import x

from sympy import Poly

from sympy.solvers.inequalities import solve_rational_inequalities

# %%
sympy.init_printing(use_unicode=True)

# %%
def convert_input(string):
    expr = sympy.sympify(string, evaluate=False)
    sym, = expr.free_symbols
    x = sympy.Symbol(sym.name, real=True)
    expr = expr.subs(sym, x)
    #expr = expr.subs(UnevaluatedExpr(sym), x)
    return expr, x

# %%
def convert_to_frac(string):
    expr = sympify(string, evaluate=False)
    sym, = expr.free_symbols
    x = Symbol(sym.name, real=True)
    expr = expr.subs(sym, x)
    frac = cancel(together(expr))
    return frac, x

# %%
def plot_curve(expr, x, x_min, x_max, y_min, y_max):
    """Plot y=expr(x) over the specified domain."""
    func = sympy.lambdify([x], expr)
    xs = np.linspace(x_min, x_max, 9000)
    plt.plot(xs, func(xs), label=str(expr))
    plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
               ncol=2, mode="expand", borderaxespad=0.)
    plt.ylim(y_min, y_max)
    plt.xlim(x_min, x_max)
    plt.grid(True)

# %%
def plot_three(string1, string2, x_min, x_max, y_min, y_max):
    expr0, expr1, expr2 = make_expr(string1, string2)
    for expression in [expr0, expr1, expr2]:
        plot_curve(expression, x, x_min, x_max, y_min, y_max)

# %%
def make_expr(string1, string2):
    
    string0 = string1 + ' - (' + string2 + ')'
    
    expr0, x = convert_input(string0)
    expr1, x = convert_input(string1)
    expr2, x = convert_input(string2)
    
    return [expr0, expr1, expr2]

# %%
def compare_solutions(string1, string2):
    expr0, expr1, expr2 = make_expr(string1, string2)
    return solve(simplify(expr0)) == solve(Eq(expr1, expr2))

# %%
def slv(string1, string2):
    expr0, expr1, expr2 = make_expr(string1, string2)
    return solve(Eq(expr1, expr2))

# %% [markdown]
# # 17. find domain and range graphically

# %% [markdown]
# 17. $$ f(x) = x^{2} + 4x + 3 $$

# %%
expr, x = convert_input('x**2 + 4*x + 3')

# %%
expr
# Out:
#  2
# x  + 4⋅x + 3

# %%
fig = plt.figure()
plot_curve(expr, x, -10, 10, -10, 10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 19. find domain and range graphically

# %% [markdown]
# $$ f(x) = \sqrt{x - 1} $$

# %%
expr19, x = convert_input('sqrt((x - 1))')

# %%
expr19
# Out:
#   _______
# ╲╱ x - 1

# %%
fig = plt.figure()
plot_curve(expr19, x, 1, 17, -1, 4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 21. find domain and range graphically

# %% [markdown]
# $$ f(x) = \sqrt{16 - x^{2}} $$

# %%
expr21, x = convert_input('sqrt((16 - x**2))')

# %%
expr21
# Out:
#    _________
#   ╱       2
# ╲╱  16 - x

# %%
fig = plt.figure()
plot_curve(expr21, x, -4, 4, -1, 5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sympy.solveset(expr21, x, domain=sympy.S.Reals)
# Out:
# {-4, 4}

# %% [markdown]
# # 27. a) Solve graphically

# %% [markdown]
# $$ x^{3} + 3x^{2} = -x^{2} + 3x + 7 $$

# %%
fig = plt.figure()
expr27_1, x = convert_input('x**3 + 3*x**2')
expr27_2, x = convert_input('-x**2 + 3*x + 7')
plot_curve(expr27_1, x, -30, 30, -100, 100)
plot_curve(expr27_2, x, -30, 30, -100, 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 35. A function f is given.
# ### (a) Use a graphing calculator to draw the graph of f.
# ### (b) Find the domain and range of f.
# ### (c) State approximately the intervals on which f is increasing and on which f is decreasing.
#
# ## $$ f(x) = x^{2} - 5x $$

# %%
fig = plt.figure()
expr35, x = convert_input('x**2 - 5*x')
plot_curve(expr35, x, -20, 20, -100, 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 41. A function f is given.
# ### (a) Use a graphing calculator to draw the graph of f.
# ### (b) Find the domain and range of f.
# ### (c) State approximately the intervals on which f is increasing and on which f is decreasing.
#
# ## $$ f(x) = x^{2/5} $$

# %%
fig = plt.figure()
expr35, x = convert_input('(x**2)**(1/5)') # do not write x**(2/5); produces ERROR
plot_curve(expr35, x, -1030, 1030, 0, 35)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 47. A function is given.
# ### (a) Find all the local maximum and minimum values of the function and the value of x at which each occurs. State each answer rounded to two decimal places.
#
# ### (b) Find the intervals on which the function is increasing and on which the function is decreasing. State each answer rounded to two decimal places.
#
# ## $$ f(x) = x^{3} - x $$

# %%
fig = plt.figure()
expr35, x = convert_input('x**3 - x')
plot_curve(expr35, x, -1, 1, -0.5, 0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
